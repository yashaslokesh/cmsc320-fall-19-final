# %% [markdown]
# # How do acoustic features of songs influence their rank?

# %% [markdown]
# Authors: Yashas Lokesh, Renee Yang, Kavya Dagli

# %% [markdown]
# Musicologist Dr. Alison Pawley and psychologist Dr. Daniel Mullensiefen out at the University of London claim that it is possible to identify if a song will be popular. Two of the attributes that they predict make songs popular are "longer and detailed musical phrases" and "a higher number of pitches." We will put this claim to the test by analyzing the relationship between song audio features and song rank. We will also explore if there are additional features that influence popularity.

# %% [markdown]
# ![](billboard_img.jpg)

# %% [markdown]
# # 1. Getting Started

# %% [markdown]
# ## 1.1 Required Libraries

# %%
import pandas as pd
import sqlite3
import sqlalchemy as db
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model 
from sklearn import model_selection
from statsmodels import api as sm

# %% [markdown]
# ## 1.2 Dataset Source

# %% [markdown]
# The dataset we use is scraped comes from two different sources. The first source is the Billboard Top 100 data over 100 years. This dataset includes the rank of albums overtime.
#
# This data can be accessed here: LINK
#
# The second source comes from AllMusic. This dataset includes songs in albums and various audio features of each song such as instrumentalness, energy, and valence.
#
# This data can be accessed here: LINK

# %% [markdown]
# ## 1.3 Load and View Data

# %%
#connect to database
engine = db.create_engine('sqlite:///billboard-200.db')
conn = engine.connect()

# %%
#convert acoustic_features table to dataframe
acoustic_features = pd.read_sql_table('acoustic_features', conn)
acoustic_features.head()
# Out:
#                        id                                song       album  \
# 0  0Veyvc3n9AcLSoK3r1dA12                   Voices In My Head  Hoodie SZN
# 1  77JzXZonNumWsuXKy9vr3U                              Beasty  Hoodie SZN
# 2  18yllZD0TdF7ykcREib8Z1                            I Did It  Hoodie SZN
# 3  1wJRveJZLSb1rjhnUHQiv6             Swervin (feat. 6ix9ine)  Hoodie SZN
# 4  0jAfdqv18goRTUxm3ilRjb  Startender (feat. Offset and Tyga)  Hoodie SZN
#
#                    artist  acousticness  danceability  duration_ms  energy  \
# 0  A Boogie Wit da Hoodie        0.0555         0.754     142301.0   0.663
# 1  A Boogie Wit da Hoodie        0.2920         0.860     152829.0   0.418
# 2  A Boogie Wit da Hoodie        0.1530         0.718     215305.0   0.454
# 3  A Boogie Wit da Hoodie        0.0153         0.581     189487.0   0.662
# 4  A Boogie Wit da Hoodie        0.0235         0.736     192779.0   0.622
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000  6.0     0.101    -6.311   0.0        0.427   90.195
# 1          0.000000  7.0     0.106    -9.061   0.0        0.158  126.023
# 2          0.000046  8.0     0.116    -9.012   1.0        0.127   89.483
# 3          0.000000  9.0     0.111    -5.239   1.0        0.303   93.023
# 4          0.000000  6.0     0.151    -4.653   0.0        0.133  191.971
#
#    time_signature  valence                album_id        date
# 0             4.0    0.207  3r5hf3Cj3EMh1C2saQ8jyt  2018-12-21
# 1             4.0    0.374  3r5hf3Cj3EMh1C2saQ8jyt  2018-12-21
# 2             4.0    0.196  3r5hf3Cj3EMh1C2saQ8jyt  2018-12-21
# 3             4.0    0.434  3r5hf3Cj3EMh1C2saQ8jyt  2018-12-21
# 4             4.0    0.506  3r5hf3Cj3EMh1C2saQ8jyt  2018-12-21

# %%
acoustic_features.describe()
# Out:
#         acousticness   danceability   duration_ms         energy  \
# count  339850.000000  339850.000000  3.398500e+05  339850.000000
# mean        0.298806       0.541176  2.367351e+05       0.616716
# std         0.315533       0.170821  1.022557e+05       0.244043
# min         0.000000       0.000000  1.062000e+03       0.000000
# 25%         0.021500       0.425000  1.865218e+05       0.440000
# 50%         0.164000       0.547000  2.263730e+05       0.647000
# 75%         0.546000       0.664000  2.710000e+05       0.822000
# max         0.996000       0.988000  4.734079e+06       1.000000
#
#        instrumentalness            key       liveness       loudness  \
# count     339850.000000  339850.000000  339850.000000  339850.000000
# mean           0.098277       5.239526       0.233439      -9.072759
# std            0.241980       3.553370       0.215256       4.601032
# min            0.000000       0.000000       0.000000     -60.000000
# 25%            0.000000       2.000000       0.098200     -11.575000
# 50%            0.000053       5.000000       0.141000      -8.121000
# 75%            0.011100       8.000000       0.299000      -5.679000
# max            1.000000      11.000000       1.000000       3.744000
#
#                 mode    speechiness          tempo  time_signature  \
# count  339850.000000  339850.000000  339850.000000   339850.000000
# mean        0.705700       0.092625     119.933974        3.887547
# std         0.455728       0.128894      30.380899        0.453673
# min         0.000000       0.000000       0.000000        0.000000
# 25%         0.000000       0.033400      96.188250        4.000000
# 50%         1.000000       0.044700     118.223000        4.000000
# 75%         1.000000       0.084000     139.288000        4.000000
# max         1.000000       0.968000     247.824000        5.000000
#
#              valence
# count  339850.000000
# mean        0.506169
# std         0.253193
# min         0.000000
# 25%         0.302000
# 50%         0.506000
# 75%         0.712000
# max         1.000000

# %%
#convert albums table to dataframe
albums = pd.read_sql_table('albums', conn)
albums.head()
# Out:
#    id        date                  artist                              album  \
# 0   1        None                    None                               None
# 1   2  2019-01-19  A Boogie Wit da Hoodie                         Hoodie SZN
# 2   3  2019-01-19               21 Savage                       I Am > I Was
# 3   4  2019-01-19              Soundtrack  Spider-Man: Into The Spider-Verse
# 4   5  2019-01-19               Meek Mill                      Championships
#
#    rank  length   track_length
# 0  None     NaN            NaN
# 1     1    20.0  185233.800000
# 2     2    15.0  211050.733333
# 3     3    13.0  190866.384615
# 4     4    19.0  219173.894737

# %%
albums.describe()
# Out:
#                   id         length  track_length
# count  573947.000000  492547.000000  4.688670e+05
# mean   286974.000000      13.728933  2.443541e+05
# std    165684.371813       7.960640  7.195498e+04
# min         1.000000       1.000000  2.542290e+04
# 25%    143487.500000      10.000000  2.100814e+05
# 50%    286974.000000      12.000000  2.372190e+05
# 75%    430460.500000      15.000000  2.680566e+05
# max    573947.000000     666.000000  4.457023e+06

# %% [markdown]
# ## 1.4 Cleaning and Modifying Data

# %% [markdown]
# After viewing the data, it is apparent that many of the features contain null values. We decided to drop these values to prevent complications with performing operations on the two dataframes later on.

# %%
#drop null values in both tables
acoutstic_features = acoustic_features.dropna()
albums = albums.dropna()

# %% [markdown]
# We combined the two dataframes here so that the rank of each album could be accessed from the ACOUSTIC_FEATURES dataframe. We decided to extract the best rank for an album from the ALBUMS dataframe and place it in the 'rank' column of ACOUSTIC_FEATURES. We will start by creating a dictionary that maps the album to its best rank.

# %%
#function to get highest rank for albums
def highest_rank(df, album):
    target = df[df.album == album]
    #"highest" rank means lowest value in rank column 
    return target['rank'].min()

#populate dictionary with highest rank of each album
ranks = {}
for a in albums["album"].unique():
    ranks[a] = highest_rank(albums, a)

# %% [markdown]
# Now that we have mapped albums to their best rank, we will create the 'rank' column in ACOUSTIC_FEATURES. We noticed that some albums in ACOUSTIC_FEATURES do not appear in ALBUMS so we could not get a best rank for them. In this case we set that album's rank as NaN and dropped the row.

# %%
#create rank column in ACOUSTIC_FEATURES 
col = []
for index, row in acoustic_features.iterrows():
    '''
    if album exists in ACOUSTIC_FEATURES place, 
    otherwise set to null
    '''
    try:
        col.append(int(ranks[row['album']]))
    except:
        col.append(np.nan)
acoustic_features['rank'] = col

# %% [markdown]
# Finally, we have a table containing all song's acoustic features and their album's corresponding rank!

# %%
#drop any null values we set in the above step
acoustic_features = acoustic_features.dropna()
acoustic_features.head()
# Out:
#                        id                                song       album  \
# 0  0Veyvc3n9AcLSoK3r1dA12                   Voices In My Head  Hoodie SZN
# 1  77JzXZonNumWsuXKy9vr3U                              Beasty  Hoodie SZN
# 2  18yllZD0TdF7ykcREib8Z1                            I Did It  Hoodie SZN
# 3  1wJRveJZLSb1rjhnUHQiv6             Swervin (feat. 6ix9ine)  Hoodie SZN
# 4  0jAfdqv18goRTUxm3ilRjb  Startender (feat. Offset and Tyga)  Hoodie SZN
#
#                    artist  acousticness  danceability  duration_ms  energy  \
# 0  A Boogie Wit da Hoodie        0.0555         0.754     142301.0   0.663
# 1  A Boogie Wit da Hoodie        0.2920         0.860     152829.0   0.418
# 2  A Boogie Wit da Hoodie        0.1530         0.718     215305.0   0.454
# 3  A Boogie Wit da Hoodie        0.0153         0.581     189487.0   0.662
# 4  A Boogie Wit da Hoodie        0.0235         0.736     192779.0   0.622
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000  6.0     0.101    -6.311   0.0        0.427   90.195
# 1          0.000000  7.0     0.106    -9.061   0.0        0.158  126.023
# 2          0.000046  8.0     0.116    -9.012   1.0        0.127   89.483
# 3          0.000000  9.0     0.111    -5.239   1.0        0.303   93.023
# 4          0.000000  6.0     0.151    -4.653   0.0        0.133  191.971
#
#    time_signature  valence                album_id        date  rank
# 0             4.0    0.207  3r5hf3Cj3EMh1C2saQ8jyt  2018-12-21   1.0
# 1             4.0    0.374  3r5hf3Cj3EMh1C2saQ8jyt  2018-12-21   1.0
# 2             4.0    0.196  3r5hf3Cj3EMh1C2saQ8jyt  2018-12-21   1.0
# 3             4.0    0.434  3r5hf3Cj3EMh1C2saQ8jyt  2018-12-21   1.0
# 4             4.0    0.506  3r5hf3Cj3EMh1C2saQ8jyt  2018-12-21   1.0

# %% [markdown]
# # 2. Exploring Popular Songs

# %% [markdown]
# ## 2.1 Audio Features of Top Songs

# %% [markdown]
# Now that we have modified our ACOUSTIC_FEATURES dataset to our linking, let's start by exploring the top songs in the dataset. Top songs are those that belong to albums with a number one ranking, as indicated by the 'rank' column. We will first isolate the top songs into their own dataframe.

# %%
#isolate songs that were ranked at #1
top_songs = acoustic_features[acoustic_features['rank'] == 1]
len(top_songs)
# Out:
# 13626

# %% [markdown]
# We are able to find 13626 top songs in our table! Here are a few #1 hits:

# %%
top_songs.sample(n=5)
# Out:
#                             id  \
# 68528   0v9rRrrRi3xxd4M9moRxyH
# 33079   27H08UOnOSclCklRLojBFY
# 109894  7xqeIdLJSf3bgmZ7vUvHrE
# 211861  2h9o31sWMWQlHcKaMipeUq
# 745     5gTWvPbdGBBijcIHueACbv
#
#                                                   song         album  \
# 68528                                   Hungover Heart  Set You Free
# 33079                                           Driver          Home
# 109894                                       Idioteque         Kid A
# 211861  Hello, Goodbye - Take 16 / Anthology 2 Version   Anthology 2
# 745                                 American Bad Dream    Experiment
#
#               artist  acousticness  danceability  duration_ms  energy  \
# 68528     Gary Allan        0.6680         0.497     227547.0   0.599
# 33079   Blue October        0.1040         0.553     281799.0   0.609
# 109894     Radiohead        0.0352         0.615     309093.0   0.931
# 211861   The Beatles        0.4330         0.474     197933.0   0.852
# 745       Kane Brown        0.0300         0.579     198000.0   0.771
#
#         instrumentalness   key  liveness  loudness  mode  speechiness  \
# 68528           0.005230   5.0    0.1260    -7.397   1.0       0.0333
# 33079           0.353000   1.0    0.6090    -8.577   0.0       0.0302
# 109894          0.000024   3.0    0.0914    -7.800   1.0       0.2400
# 211861          0.000011   0.0    0.4790    -6.840   1.0       0.0366
# 745             0.000002  10.0    0.2980    -5.497   0.0       0.0380
#
#           tempo  time_signature  valence                album_id        date  \
# 68528   140.416             4.0    0.383  6PcLI5dTPttZi5OrhqcBSA        2013
# 33079   164.983             4.0    0.251  41kJiMFPVIfh06Ojk8Udxt  2016-04-22
# 109894  137.544             3.0    0.530  19RUXBFyM4PpmrLRdtqWbp  2000-10-01
# 211861  100.217             4.0    0.800  3Lf8VA23cMAl5imbABTZoo  1996-03-18
# 745     140.196             4.0    0.609  5F5RuYUEtxLiByZVVCkoUs  2018-11-09
#
#         rank
# 68528    1.0
# 33079    1.0
# 109894   1.0
# 211861   1.0
# 745      1.0

# %% [markdown]
# Now we will average each audio feature to get an idea of the audio features for popular songs.

# %%
#grab audio feature columns
top_song_avg = top_songs.loc[:,'acousticness':'valence'].mean()
top_song_avg = top_song_avg.sort_values()
top_song_avg
# Out:
# loudness                -8.200638
# instrumentalness         0.063410
# speechiness              0.104092
# liveness                 0.211498
# acousticness             0.264981
# valence                  0.498196
# danceability             0.568460
# energy                   0.630837
# mode                     0.677969
# time_signature           3.907750
# key                      5.258697
# tempo                  119.231669
# duration_ms         237258.667914
# dtype: float64

# %% [markdown]
# We are dropping some of the very large and very small values for the purpose of graphing, but don't worry we'll include them in our analysis.

# %%
top_song_avg = top_song_avg.drop(labels=['duration_ms', 'tempo', 'loudness'])

# %% [markdown]
# Here is a plot of the average features of #1 ranked songs:

# %%
plt.style.use('seaborn-poster')

# %%
#plot audio features for high-ranked songs
plt.figure(figsize=(25,15))
plt.title("Avereage Audio Features of Top Songs", fontsize=20)
plt.xlabel("Audio Features", fontsize=20)
plt.ylabel("Average Value", fontsize=20)
plt.bar(top_song_avg.keys(),top_song_avg)
plt.show()

# %% [markdown]
# ## 2.2 Popular Songs vs. Low Ranked Songs

# %% [markdown]
# In order to compare the audio features of low-ranked songs to high-ranked songs, let's first look at the lowest rank in our table. We can do this by getting the value counts of the data in the 'rank' column.

# %%
#get counts of ranks
acoustic_features['rank'].value_counts().sort_index()
# Out:
# 1.0      13626
# 3.0         16
# 4.0         11
# 5.0         22
# 6.0         15
#          ...
# 196.0      897
# 197.0      906
# 198.0      934
# 199.0      710
# 200.0      830
# Name: rank, Length: 199, dtype: int64

# %% [markdown]
# Now we know that the lowest rank a song can achieve is 200. Getting the count of each rank has also indicated that we have a sizeable sample to calculate an average from! (818 songs to be exact)

# %%
#isolate low ranked songs
low_ranked = acoustic_features[acoustic_features['rank'] == 200]
low_ranked.head()
# Out:
#                           id             song               album     artist  \
# 9514  6PY0zFbmh6TWMQDDnJqKmi      Just A Fool  Uniform Distortion  Jim James
# 9515  0Evixriu8Jdn5vkXXTTCqV  You Get To Rome  Uniform Distortion  Jim James
# 9516  1kEhCIq9sfLADamf4Tm5jT      Out Of Time  Uniform Distortion  Jim James
# 9517  7FWL3U5cjcbLZxLzBKJbXC        Throwback  Uniform Distortion  Jim James
# 9518  2v96SpFC6LS53llretL3kN       No Secrets  Uniform Distortion  Jim James
#
#       acousticness  danceability  duration_ms  energy  instrumentalness   key  \
# 9514        0.4190         0.485     240040.0   0.723          0.045900   4.0
# 9515        0.1080         0.400     148200.0   0.892          0.000000  11.0
# 9516        0.0442         0.221     171760.0   0.818          0.001750   2.0
# 9517        0.0224         0.402     318800.0   0.864          0.000007   6.0
# 9518        0.3260         0.452     292533.0   0.673          0.000126  11.0
#
#       liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 9514    0.1510    -6.729   1.0       0.0438  118.143             4.0    0.515
# 9515    0.3060    -4.427   0.0       0.0899  129.838             4.0    0.382
# 9516    0.2280    -5.788   1.0       0.0864  102.079             4.0    0.261
# 9517    0.0777    -5.316   1.0       0.0481  117.281             4.0    0.487
# 9518    0.0986    -6.037   1.0       0.0329  112.050             4.0    0.290
#
#                     album_id        date   rank
# 9514  7bDsFXWrq3zXuyQlIzJU6j  2018-06-29  200.0
# 9515  7bDsFXWrq3zXuyQlIzJU6j  2018-06-29  200.0
# 9516  7bDsFXWrq3zXuyQlIzJU6j  2018-06-29  200.0
# 9517  7bDsFXWrq3zXuyQlIzJU6j  2018-06-29  200.0
# 9518  7bDsFXWrq3zXuyQlIzJU6j  2018-06-29  200.0

# %%
#get audio features for low ranked songs 
low_ranked_avg = low_ranked.loc[:,'acousticness':'valence'].mean()
low_ranked_avg = low_ranked_avg.sort_values()
low_ranked_avg
# Out:
# loudness                -8.003887
# speechiness              0.079857
# instrumentalness         0.122415
# liveness                 0.235199
# acousticness             0.262511
# valence                  0.501521
# danceability             0.522401
# energy                   0.662895
# mode                     0.707229
# time_signature           3.883133
# key                      5.490361
# tempo                  121.249167
# duration_ms         242261.644578
# dtype: float64

# %% [markdown]
# Again dropping very low and very high values...

# %%
low_ranked_avg = low_ranked_avg.drop(labels=['duration_ms', 'tempo', 'loudness'])

# %% [markdown]
# Since we have the average data for the lowest and highest ranked songs we can graph them side-by-side and see if the value differ

# %%
#create side-by-side bar graph for low vs high ranked songs
ind = np.arange(len(low_ranked_avg))  
#set distance between bars
width = 0.35       

fig = plt.figure(figsize=(25,15))
ax = fig.add_subplot(111)
avgs1 = ax.bar(ind, top_song_avg, width, color='#CC998D')
avgs2 = ax.bar(ind+width, low_ranked_avg, width, color='#429EA6')

ax.set_ylabel('Average Value', fontsize=20)
ax.set_xlabel('Audio Features', fontsize=20)
ax.set_title('Average Audio Features of High and Low Ranked Songs')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(top_song_avg.keys())
ax.legend( (avgs1[0], avgs2[0]), ('High Rated', 'Low Rated') )
plt.show()

# %% [markdown]
# **Observations**
#
# - There are no drastic differences between features of low and high rated songs
# - 'key' is higher for low-rated songs
# - high-rated songs are slightly longer
# - all other features are higher in value for low-rated songs, exept for danceability

# %% [markdown]
# A bar graph of the difference in each feature will better demonstrate the change in average feature value between low and high rated songs.

# %%
#get difference between values for high and low ranked songs
diffs = [a - b for a, b in zip(low_ranked_avg, top_song_avg)]

#plot
plt.figure(figsize=(25,15))
plt.title("Avereage Audio Features of Top Songs", fontsize=20)
plt.xlabel("Audio Features", fontsize=20)
plt.ylabel("Average Value", fontsize=20)
plt.bar(top_song_avg.keys(),diffs)
plt.show()

# %% [markdown]
# **Observations**
#
# - The highest difference between averages is for 'key'
# - The second highest difference is for 'dancibility'
# - All other differences seem to be less than or around 0.25
#
# This may indicate that key and dancibility are highly influenctial in determining a song's rank. To evaluate this, we will determine the correlation of these factors in our analysis section.

# %% [markdown]
# # 3. Exploring Middle Ground

# %% [markdown]
# ## 3.1 Slicing Ranks

# %% [markdown]
# Since there was the greatest difference in the average value for the 'key' of top-ranked songs and low-ranked songs, we decided to look at what the value of 'key' was for other levels of rank. We did this by creating a violin-plot where we demonstrate the distribution of 'key' value for each level of rank. Since ranks can be 1-200, we will begin by slicing the ranks into groups of 10 (<= 10, <=20, etc.)

# %%
#convert rank column to int for binning
acoustic_features['rank'] = acoustic_features['rank'].astype(int)
#bin rank values
acoustic_features['rank_bins'] = pd.cut(acoustic_features['rank'], np.arange(0,201,10))
acoustic_features.loc[0:5,'rank':'rank_bins']
# Out:
#    rank rank_bins
# 0     1   (0, 10]
# 1     1   (0, 10]
# 2     1   (0, 10]
# 3     1   (0, 10]
# 4     1   (0, 10]
# 5     1   (0, 10]

# %% [markdown]
# ## 3.2 Measuring Distrubution of 'Key' per Rank

# %%
#plot distributions for key value
plt.figure(figsize=(20, 6))
plt.title("Distribution of Key per Rank Bin")
ax = sns.violinplot(x=acoustic_features["rank_bins"], y=acoustic_features['key'])

# %% [markdown]
# **Observations**
#
# - There is no clear change in key from high to low ranks
# - Highly-ranked songs do seem to have a slightly lower key than lower ranks
# - Many songs seem to have low key values or high key values relative to the range of values

# %% [markdown]
# ## 3.3 Measuring Distribution of 'Danceability' per Rank

# %%
#plot distributions for danceability level
plt.figure(figsize=(20, 6))
plt.title("Distribution of Danceability per Rank Bin")
ax = sns.violinplot(x=acoustic_features["rank_bins"], y=acoustic_features['danceability'])

# %% [markdown]
# **Observations**
#
# - Most distributions are symmetrical
# - Even though danceability levels differ by rank, the levels tend to be similar for inviduals ranks
# - Danceability levels for high ranks seems to be slightly higher than very low ranks

# %% [markdown]
# # 4. Audio Features vs. Rank Analysis

# %% [markdown]
# ## 4.1 Audio Features vs. Rank

# %% [markdown]
# We will now do a formal analysis of the correlation between audio features and rank. To begin, let's make a correlation dataframe using the all the audio features and the rank column in ACOUSTIC_FEATURES.

# %%
#creates list of audio features
variables = list(acoustic_features.columns[4:17])
'''
add rank to list because we want to measure
it's correlation to the audio features
'''
variables.insert(0,'rank')

#create correlation dataframe
corr_df = acoustic_features[variables]
corr_df = corr_df.corr()
corr_df = corr_df.round(3)
corr_df
# Out:
#                    rank  acousticness  danceability  duration_ms  energy  \
# rank              1.000         0.028        -0.039       -0.000  -0.009
# acousticness      0.028         1.000        -0.182       -0.127  -0.701
# danceability     -0.039        -0.182         1.000       -0.058   0.091
# duration_ms      -0.000        -0.127        -0.058        1.000   0.068
# energy           -0.009        -0.701         0.091        0.068   1.000
# instrumentalness  0.065         0.096        -0.176        0.043  -0.094
# key               0.004        -0.023         0.023        0.005   0.030
# liveness          0.016        -0.000        -0.152        0.062   0.162
# loudness         -0.039        -0.556         0.124        0.049   0.756
# mode              0.014         0.081        -0.071       -0.050  -0.068
# speechiness      -0.011         0.015         0.173       -0.084   0.099
# tempo             0.004        -0.172        -0.121        0.018   0.210
# time_signature   -0.014        -0.185         0.204        0.061   0.190
# valence           0.012        -0.212         0.523       -0.123   0.302
#
#                   instrumentalness    key  liveness  loudness   mode  \
# rank                         0.065  0.004     0.016    -0.039  0.014
# acousticness                 0.096 -0.023    -0.000    -0.556  0.081
# danceability                -0.176  0.023    -0.152     0.124 -0.071
# duration_ms                  0.043  0.005     0.062     0.049 -0.050
# energy                      -0.094  0.030     0.162     0.756 -0.068
# instrumentalness             1.000 -0.007    -0.026    -0.244 -0.039
# key                         -0.007  1.000    -0.000     0.016 -0.164
# liveness                    -0.026 -0.000     1.000     0.034  0.009
# loudness                    -0.244  0.016     0.034     1.000 -0.031
# mode                        -0.039 -0.164     0.009    -0.031  1.000
# speechiness                 -0.103  0.032     0.230    -0.006 -0.085
# tempo                       -0.016 -0.003    -0.001     0.166  0.016
# time_signature              -0.042  0.006    -0.017     0.167 -0.016
# valence                     -0.139  0.028    -0.029     0.159 -0.002
#
#                   speechiness  tempo  time_signature  valence
# rank                   -0.011  0.004          -0.014    0.012
# acousticness            0.015 -0.172          -0.185   -0.212
# danceability            0.173 -0.121           0.204    0.523
# duration_ms            -0.084  0.018           0.061   -0.123
# energy                  0.099  0.210           0.190    0.302
# instrumentalness       -0.103 -0.016          -0.042   -0.139
# key                     0.032 -0.003           0.006    0.028
# liveness                0.230 -0.001          -0.017   -0.029
# loudness               -0.006  0.166           0.167    0.159
# mode                   -0.085  0.016          -0.016   -0.002
# speechiness             1.000 -0.035          -0.011    0.043
# tempo                  -0.035  1.000           0.056    0.093
# time_signature         -0.011  0.056           1.000    0.158
# valence                 0.043  0.093           0.158    1.000

# %% [markdown]
# We can use the correlation dataframe to create a heat map which will provide a visual representation of the correlation between each column in our dataframe.

# %%
plt.figure(figsize=(20,10))
plt.title("Correlation Heatmap of Rank and Audio Features", fontsize=20)
sns.heatmap(corr_df, cmap=sns.diverging_palette(220, 10, as_cmap=True), square=True, annot=True)
plt.show()

# %% [markdown]
# **Observations**
#
# - Unfortunately, no audio feature is highly correlated to rank. The highest correlated audio feature to rank is instrumentalness (this represents the amount of vocals in a song).
# - Danceability and key are very low correlated to rank
# - Loudness and energy are highly correlated. This is not surprising as the two audio features are often associated.

# %% [markdown]
# ## 4.2 Audio Features vs. Rank by Decade

# %% [markdown]
# Since there was little correlation between rank and audio features, we decided to go ahead and try slitting the songs up by decade to see if this affected results. To see if time has an affect on correlation between audio features and rank, we will create a heat map for 10 different time periods. In order to do this, we can convert the date column from the string type to the DateTime object type. We then create bins by using pandas' date_range function and create the bin column using pandas' cut function.

# %%
#convert date column from string to DateTime object
ft_date = acoustic_features.copy(deep=True)
ft_date['date'] = ft_date['date'].astype('datetime64[ns]')
#get min and max date
low = ft_date['date'].min()
high = ft_date['date'].max()
#create bins
bins_dt = pd.date_range(start='1899-01-01 00:00:00', end='2020-04-08 00:00:00', periods=10)
#create bins column 
ft_date['date_bins'] = pd.cut(ft_date.date,bins=bins_dt)
ft_date.sample(n=3)
# Out:
#                             id                                 song  \
# 314056  6YCoBuF83psftrfm6Xvhxe             Partial Belated Overture
# 202169  48xXxVHaSxNiAELpnkJpx3                      Floaters in Mud
# 123687  22LwhIWG9emahUJCGPWLT0  Too Bright To See, Too Loud To Hear
#
#                                   album                  artist  acousticness  \
# 314056                              'U'  Incredible String Band      0.924000
# 202169                          Against               Sepultura      0.000059
# 123687  Lost In The Sound Of Separation               Underoath      0.017900
#
#         danceability  duration_ms  energy  instrumentalness   key  ...  mode  \
# 314056         0.380     175427.0   0.296             0.771   2.0  ...   1.0
# 202169         0.322     298600.0   0.816             0.130  11.0  ...   0.0
# 123687         0.451     270853.0   0.814             0.115   7.0  ...   0.0
#
#         speechiness    tempo  time_signature  valence                album_id  \
# 314056       0.0405  108.719             4.0    0.606  7fBC2M8NZs82NYgHnus4oy
# 202169       0.0644  105.225             4.0    0.395  5FPGRBTLFa58YLTKhTzSrT
# 123687       0.0705  120.136             4.0    0.257  613KEpSUb8NIzGmpfqhXAw
#
#              date rank   rank_bins                                   date_bins
# 314056 1970-01-01  183  (180, 190]           (1966-05-16 16:00:00, 1979-11-06]
# 202169 1998-10-06  139  (130, 140]  (1993-04-27 08:00:00, 2006-10-17 16:00:00]
# 123687 2008-01-01  110  (100, 110]           (2006-10-17 16:00:00, 2020-04-08]
#
# [3 rows x 22 columns]

# %% [markdown]
# Now that we've but our songs into bins, we can create the heatmaps for each time period!

# %%
for item in ft_date['date_bins'].unique():
    curr = ft_date[ft_date['date_bins'] == item]
    curr = curr[variables]
    print("Length of Dataset:", len(curr))
    curr = curr.corr()
    curr = curr.round(3)
    plt.figure(figsize=(20,10))
    plt.title(str("Correlation Heatmap of Rank and Audio Features for: " + str(item)), fontsize=20)
    sns.heatmap(curr, cmap=sns.diverging_palette(220, 10, as_cmap=True), square=True, annot=True)
    plt.show()
# Out:
# Length of Dataset: 133692
# Length of Dataset: 84072
# Length of Dataset: 39496
# Length of Dataset: 46240
# Length of Dataset: 7803
# Length of Dataset: 79
# Length of Dataset: 12

# %% [markdown]
# **Observations**
#
# Correlations from rank to acoustic features remain weak until the time periods between 1899 and 1952. Upon further exploration, we found that this was because the datasets for these time periods were extremely small in comaprison to the datasets for later time periods. In order words, there is less variance in the data. Because we cannot rely on the heatmaps of earlier years to draw conclusions, we can conclude that splitting the data into time periods does not show a strong correlation between rank and acoustic features.

# %% [markdown]
# # 5. Linear Regression

# %% [markdown]
# ## 5.1 Null Hypothesis

# %% [markdown]
# Our null hypothesis states that none of the acoustic features will influence rank.
#
# In the next step, we will verify the null hypothesis.

# %% [markdown]
# ## 5.2. Regression with scikit-learn

# %% [markdown]
# Regression will allow us to determine the strength of the relationship between the rank (our dependent variable) and the audio features (our independent variable).
#
# To begin our regression we will create two separate dataframe for our independent and dependent variables. Our independent variables will reside in the features dataframe and our dependent variables will reside in the target dataframe.

# %%
features = acoustic_features.loc[:,'acousticness':'valence']
target = acoustic_features['rank']

# %% [markdown]
# We will now perform a regression analysis with scikit-learn. Scikit-learn allows us to pass in our data and derive a linear model from it. We can determine the success of the model by getting an R-squared score. R-squared is a metric which shows how close the data is to the generated regression line. A score of 0 means that the model does not explain the variability of the data, while a score of 1 means that the model does explain the variablity.

# %%
linreg = linear_model.LinearRegression()
model = linreg.fit(features,target)
linreg.score(features,target)
# Out:
# 0.008028078690946128

# %%
for f, c in zip(features.columns, list(linreg.coef_)):
    result = f + ": " + str(c) + "\n"
    print(result)
# Out:
# acousticness: 3.8271887853087803
#
# danceability: -11.434136814061446
#
# duration_ms: 1.39931162124185e-06
#
# energy: 6.588940136205918
#
# instrumentalness: 11.172808590276821
#
# key: 0.08711018140007754
#
# liveness: 1.9856595252184894
#
# loudness: -0.39276194479950544
#
# mode: 1.3238189987607123
#
# speechiness: -1.9752874640856335
#
# tempo: -0.0016978265597273993
#
# time_signature: -0.579408570418416
#
# valence: 8.13197897137487

# %% [markdown]
# ## 5.3. Regression with OLS

# %%
sm_y = target
sm_X = features

sm_X = sm.add_constant(features)

OLS_model = sm.OLS(target,features).fit()
OLS_model.summary()
# Out:
# /Users/lokeshkrishnappa/miniconda3/envs/cmsc320/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   rank   R-squared (uncentered):                   0.843
# Model:                            OLS   Adj. R-squared (uncentered):              0.843
# Method:                 Least Squares   F-statistic:                          1.284e+05
# Date:                Mon, 16 Dec 2019   Prob (F-statistic):                        0.00
# Time:                        06:01:12   Log-Likelihood:                     -1.6440e+06
# No. Observations:              311394   AIC:                                  3.288e+06
# Df Residuals:                  311381   BIC:                                  3.288e+06
# Df Model:                          13
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# acousticness        17.9925      0.370     48.593      0.000      17.267      18.718
# danceability         8.0095      0.625     12.823      0.000       6.785       9.234
# duration_ms       1.486e-05   8.77e-07     16.938      0.000    1.31e-05    1.66e-05
# energy              40.9941      0.607     67.489      0.000      39.804      42.185
# instrumentalness     8.9277      0.389     22.939      0.000       8.165       9.690
# key                  0.3683      0.024     15.288      0.000       0.321       0.415
# liveness             2.4200      0.434      5.582      0.000       1.570       3.270
# loudness            -1.8377      0.027    -67.710      0.000      -1.891      -1.785
# mode                 4.1986      0.189     22.247      0.000       3.829       4.568
# speechiness         -7.6589      0.713    -10.747      0.000      -9.056      -6.262
# tempo                0.0847      0.003     30.458      0.000       0.079       0.090
# time_signature       9.9405      0.160     62.178      0.000       9.627      10.254
# valence              0.2059      0.431      0.478      0.633      -0.639       1.051
# ==============================================================================
# Omnibus:                    20664.823   Durbin-Watson:                   0.182
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            25285.203
# Skew:                          -0.656   Prob(JB):                         0.00
# Kurtosis:                       3.475   Cond. No.                     2.44e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.44e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # 6. Precting Song Rank Using Audio Features

# %% [markdown]
# # Sandbox

# %%
year_slices = ['196', '197', '198', '199', '200', '201']

# %%
for s in year_slices:
    plt.figure()
    
    sliced_df = df.loc[df.date.apply(lambda x: x[:3] == s)]
    
    scs.scatterplot(x='acousticness',
                y='danceability',
                hue='album',
                legend=False,
                data=sliced_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-77953bb63206> in <module>
#       2     plt.figure()
#       3
# ----> 4     sliced_df = df.loc[df.date.apply(lambda x: x[:3] == s)]
#       5
#       6     scs.scatterplot(x='acousticness',
#
# NameError: name 'df' is not defined

# %%
for s in year_slices:
    plt.figure()
    
    sliced_df = df.loc[df.date.apply(lambda x: x[:3] == s)]
    
    scs.scatterplot(x='energy',
                y='danceability',
                hue='album',
                legend=False,
                data=sliced_df)

# %%
for s in year_slices:
    plt.figure()
    
    sliced_df = df.loc[df.date.apply(lambda x: x[:3] == s)]
    
    scs.scatterplot(x='instrumentalness',
                y='speechiness',
                hue='album',
                legend=False,
                data=sliced_df)

# %%
for s in year_slices:
    plt.figure()
    
    sliced_df = df.loc[df.date.apply(lambda x: x[:3] == s)]
    
    scs.scatterplot(x='energy',
                y='tempo',
                hue='album',
                legend=False,
                data=sliced_df)
